# %%
d=bool(25)

# %%
d
# Out:
# True

# %%
b=25
c=bool(b)
c
# Out:
# True

# %%
#input function
name = input("please enter your name")
greeting ='hello'
print(greeting+' '+name)
# Out:
# please enter your namekeerthi
# hello keerthi

# %%
 print(len("saturday is a busy day for me"))
# Out:
# 29

# %%
str1= "please state your name and roll number"

# %%
str1
# Out:
# 'please state your name and roll number'

# %%
spl='2/04/2022'
spl.split("/")
spl
# Out:
# '2/04/2022'

# %%
spl='2,04,2022'
spl.split(',')
spl
# Out:
# '2,04,2022'

# %%
DOB = '2/04/2022'
a=DOB.split("/")
a
# Out:
# ['2', '04', '2022']

# %%
x=100
if x>60:
  print("pass")
  if x<60:
    print("fail")
# Out:
# pass
